# %%
from pathlib import Path
import os

# %%
"""
f=open("GlaucomaImageNames.txt", "a+")
entries = Path('GlaucomaDataset/')
for i,entry in enumerate(entries.iterdir()):
    #print(entry.name)
    i=+i
    f.write(str(entry))
    f.write("\n")
#print(i)     
f.close()

k=open("GlaucomaImageNames3.txt", "a+")
f=open("GlaucomaImageNames.txt", "r")
#contents =f.read()
for line in f:
    print(line)
    path = line
    #entries = Path(y)
    for img in os.listdir(path[0:-1]):
        #print(img)
        if img.endswith("jpeg"):
        #scriptpath = os.path.dirname(img)
            y=os.path.join(path[0:-1],img)
            print(y)
            k.write(str(y))
            k.write("\n")
    #for entry in entries.iterdir():
        #print(entry)
       # k.write(str(entry))
        #k.write("\n")
f.close() 
k.close()  

k=open("GlaucomaImageNames4.txt", "a+")
f=open("GlaucomaImageNames3.txt", "r")
for line in f:
    y=line[0:-6]
    k.write(str(y))
    k.write("\n")
f.close() 
k.close()    
"""
# Out:
# GlaucomaDataset/NO010 RE
#
# GlaucomaDataset/NO010 RE/NO010 OD 190413 POST.jpeg
# GlaucomaDataset/NO010 RE/NO010 OD 230212 PRE.jpeg
# GlaucomaDataset/NO063 RE
#
# GlaucomaDataset/NO063 RE/NO063 OD 020513 POST.jpeg
# GlaucomaDataset/NO063 RE/NO063 OD 130912 PRE.jpeg
# GlaucomaDataset/NO124 LE
#
# GlaucomaDataset/NO124 LE/NO124 OS 291113 POST.jpeg
# GlaucomaDataset/NO124 LE/NO124 OS 190813 PRE.jpeg
# GlaucomaDataset/NO037 LE
#
# GlaucomaDataset/NO037 LE/NO037 OS 230512 POST.jpeg
# GlaucomaDataset/NO037 LE/NO037 OS 090412 PRE.jpeg
# GlaucomaDataset/NO104 LE
#
# GlaucomaDataset/NO104 LE/NO104 OS 050913 POST.jpeg
# GlaucomaDataset/NO104 LE/NO104 OS 030713 PRE.jpeg
# GlaucomaDataset/NO151 RE
#
# GlaucomaDataset/NO151 RE/NO151 OD 181113 PRE.jpeg
# GlaucomaDataset/NO151 RE/NO151 OD 191213 POST.jpeg
# GlaucomaDataset/NO133 RE
#
# GlaucomaDataset/NO133 RE/NO133 OD 041113 POST.jpeg
# GlaucomaDataset/NO133 RE/NO133 OD 120913 PRE.jpeg
# GlaucomaDataset/NO183 LE
#
# ...
